# %%
import joblib
from kafka import KafkaConsumer
import json
from alert_service import send_slack_alert
import csv
import os
import pandas as pd

try:
    model = joblib.load("rf_fraud_model.pkl")
except FileNotFoundError:
    print("Error: rf_fraud_model.pkl not found. Please check the file path.")
    exit(1)

consumer = KafkaConsumer(
    'transactions',
    bootstrap_servers='localhost:9092',
    auto_offset_reset='latest',
    group_id='fraud-detectors',
    value_deserializer=lambda m: json.loads(m.decode('utf-8'))
)

print("Listening for transactions...")

header_written = False
log_file = 'fraud_logs_2.csv'

for msg in consumer:
    try:
        txn = msg.value

        required_fields = ["user_id", "amount", "location", "timestamp"]
        if not all(field in txn for field in required_fields):
            print(f"Missing fields in transaction: {txn}")
            continue

        loc_code = {'NY': 0, 'LDN': 1, 'SG': 2, 'DEL': 3, 'DXB': 4, 'HKG': 5, 'AMS': 6, 'CPT': 7}.get(txn['location'], -1)
        if loc_code == -1:
            print(f"Invalid location code for transaction: {txn}")
            continue

        features = pd.DataFrame([{
            "amount": txn["amount"],
            "loc_code": loc_code
        }])

        prediction = model.predict(features)[0]

        if prediction == 1:
            send_slack_alert(txn)
            print(f"Fraudulent txn detected: {txn}")
        else:
            print(f"Legit txn: {txn}")

        with open(log_file, 'a', newline='') as file:
            writer = csv.writer(file)
            if not header_written:
                writer.writerow(["user_id", "amount", "location", "timestamp", "prediction"])
                header_written = True
            writer.writerow([
                txn["user_id"],
                txn["amount"],
                txn["location"],
                txn["timestamp"],
                int(prediction)
            ])
            print(f"Logged transaction to {log_file}")

    except Exception as e:
        print(f"Exception: {e}, Transaction: {txn}")
        continue

print(f"Saving transaction logs to: {os.path.abspath(log_file)}")
# Out:
# Listening for transactions...
# Legit txn: {'transaction_id': 969323, 'user_id': 9894, 'amount': 5853.04, 'timestamp': '2025-08-19T16:43:45.581784', 'location': 'LDN', 'status': 'success'}
# Logged transaction to fraud_logs_2.csv
# Legit txn: {'transaction_id': 821719, 'user_id': 7209, 'amount': 6491.05, 'timestamp': '2025-08-19T16:43:46.083221', 'location': 'LDN', 'status': 'success'}
# Logged transaction to fraud_logs_2.csv
# Legit txn: {'transaction_id': 565879, 'user_id': 6857, 'amount': 8638.32, 'timestamp': '2025-08-19T16:43:46.584446', 'location': 'DEL', 'status': 'success'}
# Logged transaction to fraud_logs_2.csv
# Legit txn: {'transaction_id': 554641, 'user_id': 4723, 'amount': 3451.05, 'timestamp': '2025-08-19T16:43:47.086421', 'location': 'LDN', 'status': 'success'}
# Logged transaction to fraud_logs_2.csv
# Legit txn: {'transaction_id': 511428, 'user_id': 2227, 'amount': 1059.43, 'timestamp': '2025-08-19T16:43:47.588471', 'location': 'SG', 'status': 'success'}
# Logged transaction to fraud_logs_2.csv
# Legit txn: {'transaction_id': 488604, 'user_id': 6736, 'amount': 1092.21, 'timestamp': '2025-08-19T16:43:48.089537', 'location': 'DEL', 'status': 'success'}
# Logged transaction to fraud_logs_2.csv
# Legit txn: {'transaction_id': 241229, 'user_id': 3864, 'amount': 1764.48, 'timestamp': '2025-08-19T16:43:48.591200', 'location': 'DEL', 'status': 'success'}
# Logged transaction to fraud_logs_2.csv
# Legit txn: {'transaction_id': 847968, 'user_id': 4583, 'amount': 50.07, 'timestamp': '2025-08-19T16:43:49.091881', 'location': 'DXB', 'status': 'success'}
# Logged transaction to fraud_logs_2.csv
# Legit txn: {'transaction_id': 605050, 'user_id': 6235, 'amount': 583.59, 'timestamp': '2025-08-19T16:43:49.593658', 'location': 'NY', 'status': 'success'}
# Logged transaction to fraud_logs_2.csv
# Legit txn: {'transaction_id': 596582, 'user_id': 7569, 'amount': 215.05, 'timestamp': '2025-08-19T16:43:50.094556', 'location': 'NY', 'status': 'success'}
# Logged transaction to fraud_logs_2.csv
# Legit txn: {'transaction_id': 363812, 'user_id': 2300, 'amount': 419.13, 'timestamp': '2025-08-19T16:43:50.596067', 'location': 'NY', 'status': 'success'}
# Logged transaction to fraud_logs_2.csv
# Legit txn: {'transaction_id': 385576, 'user_id': 1731, 'amount': 70.09, 'timestamp': '2025-08-19T16:43:51.097240', 'location': 'DXB', 'status': 'success'}
# Logged transaction to fraud_logs_2.csv
# Legit txn: {'transaction_id': 272243, 'user_id': 2156, 'amount': 3455.11, 'timestamp': '2025-08-19T16:43:51.597748', 'location': 'SG', 'status': 'success'}
# Logged transaction to fraud_logs_2.csv
# Legit txn: {'transaction_id': 256666, 'user_id': 6480, 'amount': 3440.26, 'timestamp': '2025-08-19T16:43:52.098918', 'location': 'LDN', 'status': 'success'}
# Logged transaction to fraud_logs_2.csv
# Legit txn: {'transaction_id': 208090, 'user_id': 2008, 'amount': 4761.84, 'timestamp': '2025-08-19T16:43:52.599966', 'location': 'NY', 'status': 'success'}
# Logged transaction to fraud_logs_2.csv
# Legit txn: {'transaction_id':
 'status': 'success'}
# Logged transaction to fraud_logs_2.csv
# Legit txn: {'transaction_id': 422343, 'user_id': 2373, 'amount': 4989.69, 'timestamp': '2025-08-19T16:55:27.104109', 'location': 'DEL', 'status': 'success'}
# Logged transaction to fraud_logs_2.csv
# Legit txn: {'transaction_id': 622717, 'user_id': 5242, 'amount': 2160.56, 'timestamp': '2025-08-19T16:55:27.606088', 'location': 'LDN', 'status': 'success'}
# Logged transaction to fraud_logs_2.csv
# Legit txn: {'transaction_id': 121272, 'user_id': 7537, 'amount': 3869.6, 'timestamp': '2025-08-19T16:55:28.106994', 'location': 'LDN', 'status': 'success'}
# Logged transaction to fraud_logs_2.csv
# Legit txn: {'transaction_id': 338993, 'user_id': 9185, 'amount': 506.07, 'timestamp': '2025-08-19T16:55:28.608851', 'location': 'DXB', 'status': 'success'}
# Logged transaction to fraud_logs_2.csv
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 28
#      25 header_written = False
#      26 log_file = 'fraud_logs_2.csv'
# ---> 28 for msg in consumer:
#      29     try:
#      30         txn = msg.value
#
# File c:\Users\SOMEN\AppData\Local\Programs\Python\Python311\Lib\site-packages\kafka\consumer\group.py:1181, in KafkaConsumer.__next__(self)
#    1179     return self.next_v1()
#    1180 else:
# -> 1181     return self.next_v2()
#
# File c:\Users\SOMEN\AppData\Local\Programs\Python\Python311\Lib\site-packages\kafka\consumer\group.py:1189, in KafkaConsumer.next_v2(self)
#    1187     self._iterator = self._message_generator_v2()
#    1188 try:
# -> 1189     return next(self._iterator)
#    1190 except StopIteration:
#    1191     self._iterator = None
#
# File c:\Users\SOMEN\AppData\Local\Programs\Python\Python311\Lib\site-packages\kafka\consumer\group.py:1106, in KafkaConsumer._message_generator_v2(self)
#    1104 def _message_generator_v2(self):
#    1105     timeout_ms = 1000 * (self._consumer_timeout - time.time())
# -> 1106     record_map = self.poll(timeout_ms=timeout_ms, update_offsets=False)
#    1107     for tp, records in six.iteritems(record_map):
#    1108         # Generators are stateful, and it is possible that the tp / records
#    1109         # here may become stale during iteration -- i.e., we seek to a
#    1110         # different offset, pause consumption, or lose assignment.
#    1111         for record in records:
#    1112             # is_fetchable(tp) should handle assignment changes and offset
#    1113             # resets; for all other changes (e.g., seeks) we'll rely on the
#    1114             # outer function destroying the existing iterator/generator
#    1115             # via self._iterator = None
#
# File c:\Users\SOMEN\AppData\Local\Programs\Python\Python311\Lib\site-packages\kafka\consumer\group.py:645, in KafkaConsumer.poll(self, timeout_ms, max_records, update_offsets)
#     643 remaining = timeout_ms
#     644 while True:
# --> 645     records = self._poll_once(remaining, max_records, update_offsets=update_offsets)
#     646     if records:
#     647         return records
#
# File c:\Users\SOMEN\AppData\Local\Programs\Python\Python311\Lib\site-packages\kafka\consumer\group.py:692, in KafkaConsumer._poll_once(self, timeout_ms, max_records, update_offsets)
#     689     self._client.poll(timeout_ms=0)
#     691 timeout_ms = min(timeout_ms, self._coordinator.time_to_next_poll() * 1000)
# --> 692 self._client.poll(timeout_ms=timeout_ms)
#     693 # after the long poll, we should check whether the group needs to rebalance
#     694 # prior to returning data so that the group can stabilize faster
#     695 if self._coordinator.need_rejoin():
#
# File c:\Users\SOMEN\AppData\Local\Programs\Python\Python311\Lib\site-packages\kafka\client_async.py:598, in KafkaClient.poll(self, timeout_ms, future)
#     595             timeout = min(timeout, self.config['retry_backoff_ms'])
#     596         timeout = max(0, timeout)  # avoid negative timeouts
# --> 598     self._poll(timeout / 1000)
#     600 # called without the lock to avoid deadlock potential
#     601 # if handlers need to acquire locks
#     602 responses.extend(self._fire_pending_completed_requests())
#
# File c:\Users\SOMEN\AppData\Local\Programs\Python\Python311\Lib\site-packages\kafka\client_async.py:630, in KafkaClient._poll(self, timeout)
#     627 self._register_send_sockets()
#     629 start_select = time.time()
# --> 630 ready = self._selector.select(timeout)
#     631 end_select = time.time()
#     632 if self._sensors:
#
# File c:\Users\SOMEN\AppData\Local\Programs\Python\Python311\Lib\selectors.py:323, in SelectSelector.select(self, timeout)
#     321 ready = []
#     322 try:
# --> 323     r, w, _ = self._select(self._readers, self._writers, [], timeout)
#     324 except InterruptedError:
#     325     return ready
#
# File c:\Users\SOMEN\AppData\Local\Programs\Python\Python311\Lib\selectors.py:314, in SelectSelector._select(self, r, w, _, timeout)
#     313 def _select(self, r, w, _, timeout=None):
# --> 314     r, w, x = select.select(r, w, w, timeout)
#     315     return r, w + x, []
#
# KeyboardInterrupt:
